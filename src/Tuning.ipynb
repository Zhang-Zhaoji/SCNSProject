# %%
import numpy as np
from allensdk.core.brain_observatory_cache import BrainObservatoryCache
import os
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats
import seaborn as sns
from matplotlib.cm import ScalarMappable
from matplotlib.colors import Normalize
from scipy.stats import f_oneway
from collections import defaultdict
from load_data import load_data,get_SG_FR, similarity_metric
# Out:
# e:\miniconda\conda\envs\SCNS\lib\site-packages\oasis\functions.py:13: UserWarning: Could not find cvxpy. Don't worry, you can still use OASIS, just not the slower interior point methods we compared to in the papers.
#   warn("Could not find cvxpy. Don't worry, you can still use OASIS, " +

# %%
tgt_data_path = '../data/VISal_three_session_B_501929146'
print(os.path.exists(tgt_data_path))
print(os.getcwd())
ts, dff, all_roi_masks, cids, metadata, tgt_data = load_data(tgt_data_path)
position = metadata.tolist()
print('================================================')
print('Caution, the position of this file is about the brain part of', position['targeted_structure'])
print('================================================')

orientation, spatial_frequency, phase, firing_data, _ts = get_SG_FR(ts,dff,tgt_data)
# Example data: ./data/VISal_three_session_B_501929146 \n
# ts (Time Seires): 
# (113852,) \n
# dff (dataframe of firing): 
# (172, 113852)  \n
# all_roi_masks (region of interest mask):
# (172, 512, 512) \n
# cids (Cell ids):
# (172,) \n
# metadata: \n
# {'sex': 'male', 'targeted_structure': 'VISal', 'ophys_experiment_id': 501929146, 'experiment_container_id': 511510715, 'excitation_lambda': '910 nanometers', 
# 'indicator': 'GCaMP6f', 'fov': '400x400 microns (512 x 512 pixels)', 'genotype': 'Cux2-CreERT2/wt;Camk2a-tTA/wt;Ai93(TITL-GCaMP6f)/Ai93(TITL-GCaMP6f)', 
# 'session_start_time': datetime.datetime(2016, 2, 11, 9, 54, 37), 'session_type': 'three_session_B', 'specimen_name': 'Cux2-CreERT2;Camk2a-tTA;Ai93-222426', 
# 'cre_line': 'Cux2-CreERT2/wt', 'imaging_depth_um': 175, 'age_days': 111, 'device': 'Nikon A1R-MP multiphoton microscope', 'device_name': 'CAM2P.2', 'pipeline_version': '3.0'}
# Out:
# True
# d:\生科课\计算与系统神经科学\SCNSProject\src
# check subtitles, should be ['ts', 'dff', 'all_roi_masks', 'cids', 'metadata']
# ['ts', 'dff', 'all_roi_masks', 'cids', 'metadata']
# metadata:{'sex': 'male', 'targeted_structure': 'VISal', 'ophys_experiment_id': 501929146, 'experiment_container_id': 511510715, 'excitation_lambda': '910 nanometers', 'indicator': 'GCaMP6f', 'fov': '400x400 microns (512 x 512 pixels)', 'genotype': 'Cux2-CreERT2/wt;Camk2a-tTA/wt;Ai93(TITL-GCaMP6f)/Ai93(TITL-GCaMP6f)', 'session_start_time': datetime.datetime(2016, 2, 11, 9, 54, 37), 'session_type': 'three_session_B', 'specimen_name': 'Cux2-CreERT2;Camk2a-tTA;Ai93-222426', 'cre_line': 'Cux2-CreERT2/wt', 'imaging_depth_um': 175, 'age_days': 111, 'device': 'Nikon A1R-MP multiphoton microscope', 'device_name': 'CAM2P.2', 'pipeline_version': '3.0'}
# ts shape:(113852,)
# dff shape:(172, 113852)
# all_roi_masks shape:(172, 512, 512)
# cids shape:(172,)
# static_gating:
#       Unnamed: 0  orientation  spatial_frequency  phase   start     end
# 0              0          0.0               0.32   0.75     745     752
# 1              1         30.0               0.32   0.50     753     760
# 2              2         90.0               0.02   0.00     760     767
# 3              3          0.0               0.32   0.75     768     775
# 4              4         60.0               0.08   0.50     775     782
# ...          ...          ...                ...    ...     ...     ...
# 5995        5995        120.0               0.08   0.75  113590  113597
# 5996        5996        150.0               0.08   0.25  113597  113604
# 5997        5997          NaN                NaN    NaN  113605  113612
# 5998        5998         60.0               0.04   0.00  113612  113619
# 5999        5999         90.0               0.04   0.50  113620  113627
#
# [6000 rows x 6 columns]
# ================================================
# Caution, the position of this file is about the brain part of VISal
# ================================================
# d:\生科课\计算与系统神经科学\SCNSProject\src\load_data.py:138: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return np.array(firing_data), np.array(ts_data)

# %%
def extract_feature_lists(firing_data:np.ndarray,orientation:np.ndarray,spatial_frequency:np.ndarray,phase:np.ndarray):
    """
    We have firing data, orientation, spatial_frequency, phase. And we want to calculate for each category, do we have some sort of way to find if there are some relationship between them?
    shape example:
    (5805,) (5805, 172) (5805,) (5805,)
    orientation = np.array([0, 30, 60, 90, 120, 150])
    spatial_frequency = np.array([0.02, 0.04, 0.08, 0.16, 0.32])
    phase = np.array([0, 0.25, 0.5, 0.75])
    Thus, there are 6*5*4 = 120 categories.
    """
    print(f'orientation.shape={orientation.shape},firing_data.shape={firing_data.shape},spatial_frequency.shape={spatial_frequency.shape},phase.shape={phase.shape}')
    firing_datas = []
    for orientation_ in np.unique(orientation):
        for spatial_frequency_ in np.unique(spatial_frequency):
            for phase_ in np.unique(phase):
                index = np.where((orientation==orientation_)&(spatial_frequency==spatial_frequency_)&(phase==phase_))
                firing_data_ = firing_data[index]
                firing_datas.append([firing_data_,orientation_,spatial_frequency_,phase_])
    return firing_datas

def similarity_metric(firing_datas, N_neurons):
    modulation = {
        'orientation': np.zeros(N_neurons),
        'spatial_frequency': np.zeros(N_neurons),
        'phase': np.zeros(N_neurons)
    }
    
    print("Grouping data...")
    group_orientation = defaultdict(list)
    group_spatial_frequency = defaultdict(list)
    group_phase = defaultdict(list)

    for j in range(len(firing_datas)):
        o, s, p = firing_datas[j][1], firing_datas[j][2], firing_datas[j][3]
        responses = firing_datas[j][0]
        for i in range(N_neurons):
            group_orientation[(o, i)].extend(responses[:, i])
            group_spatial_frequency[(s, i)].extend(responses[:, i])
            group_phase[(p, i)].extend(responses[:, i])

    print("Computing ANOVA...")
    for i in range(N_neurons):
        # Orientation
        groups = [group_orientation[(k, i)] for k in np.unique(orientation)]
        if len(groups) > 1 and all(len(g) > 0 for g in groups):
            _, p = f_oneway(*groups)
            modulation['orientation'][i] = -np.log10(p)

        # Spatial Frequency
        groups = [group_spatial_frequency[(k, i)] for k in np.unique(spatial_frequency)]
        if len(groups) > 1 and all(len(g) > 0 for g in groups):
            _, p = f_oneway(*groups)
            modulation['spatial_frequency'][i] = -np.log10(p)

        # Phase
        groups = [group_phase[(k, i)] for k in np.unique(phase)]
        if len(groups) > 1 and all(len(g) > 0 for g in groups):
            _, p = f_oneway(*groups)
            modulation['phase'][i] = -np.log10(p)

    return modulation

def plot_modulation_radar_tiled(modulation, neuron_indices,
                                neurons_per_subplot=3,
                                subplots_per_fig=(5, 6),
                                cmap='BrBG_r',
                                title=None,
                                sig_threshold=2):  # -log10(0.01) = 2
    """
    在多个子图中批量展示神经元的调制雷达图，每个子图可以叠加多个神经元
    
    参数:
        modulation: dict，包含 orientation / sf / phase 的调制强度 (-log10(p))
        neuron_indices: list of int，要绘制的神经元编号
        neurons_per_subplot: 每个子图最多显示多少个神经元（默认 3）
        subplots_per_fig: 每张图有多少个子图（行数 x 列数），默认 (5, 6)
        cmap: 颜色映射
        title: 图表标题
        sig_threshold: 显著性阈值，默认 2（即 p < 0.01）
    """
    labels = np.array(['Orientation', 'Spatial Frequency', 'Phase'])
    num_vars = len(labels)
    angles = np.linspace(0, 2 * np.pi, num_vars, endpoint=False).tolist()
    angles += angles[:1]

    total_subplots_needed = (len(neuron_indices) + neurons_per_subplot - 1) // neurons_per_subplot
    rows, cols = subplots_per_fig
    subplots_per_figure = rows * cols

    for fig_idx in range(0, total_subplots_needed, subplots_per_figure):
        fig_start = fig_idx
        fig_end = min(fig_idx + subplots_per_figure, total_subplots_needed)
        current_batches = [neuron_indices[i*neurons_per_subplot : (i+1)*neurons_per_subplot]
                           for i in range(fig_start, fig_end)]

        fig, axes = plt.subplots(rows, cols, figsize=(cols * 4, rows * 4), subplot_kw=dict(polar=True))
        if rows == 1 and cols > 1:
            axes = axes.reshape(1, -1)
        elif cols == 1 and rows > 1:
            axes = axes.reshape(-1, 1)

        norm = Normalize(vmin=0, vmax=5)
        sm = ScalarMappable(cmap=cmap, norm=norm)
        sm.set_array([])

        for ax_idx, batch in enumerate(current_batches):
            ax = axes[ax_idx // cols, ax_idx % cols]
            title_parts = []

            for idx in batch:
                stats = np.array([
                    modulation['orientation'][idx],
                    modulation['spatial_frequency'][idx],
                    modulation['phase'][idx]
                ])
                stats = np.concatenate((stats, [stats[0]]))  # Close the radar chart

                color = sm.to_rgba(stats[:-1].mean())
                ax.plot(angles, stats, color=color, linewidth=1.5, alpha=0.8, label=f"Neuron {idx}")
                ax.fill(angles, stats, color=color, alpha=0.15)
                title_parts.append(f"{idx}")

                # 添加显著性标记 ★
                for i in range(num_vars):
                    if stats[i] > sig_threshold:
                        ax.text(angles[i], stats[i], '*', fontsize=24, ha='center', va='center')
                        # ax.plot(angles[i], stats[i], marker='*', markersize=10, color='red', linestyle='none')

            ax.set_xticks(angles[:-1])
            ax.set_xticklabels(labels, fontsize=9)
            ax.set_yticklabels([])
            ax.set_title("Neurons: " + ", ".join(title_parts), fontsize=10)

        # 关闭多余的子图
        for ax_idx in range(len(current_batches), rows * cols):
            fig.delaxes(axes.flatten()[ax_idx])

        if title is not None:
            fig.suptitle(title, fontsize=32)
        else:
            fig.suptitle(f"Modulation Profiles - Batch {fig_idx // subplots_per_figure + 1}", fontsize=32)

        fig.tight_layout()
        plt.show()


print("Step 1: Feature grouping...")
firing_datas = extract_feature_lists(firing_data, orientation, spatial_frequency, phase)
print("Step 2: Computing modulation strength...")
modulation = similarity_metric(firing_datas, N_neurons=firing_data.shape[1])
print("Step 3: Plotting radar charts...")
group1 = list(range(0, firing_data.shape[1]//2))
group2 = list(range(firing_data.shape[1]//2, firing_data.shape[1]))
plot_modulation_radar_tiled(modulation, group1, title=f"Group 1 - Neurons 0~{firing_data.shape[1]//2-1}")
plot_modulation_radar_tiled(modulation, group2, title=f"Group 2 - Neurons {firing_data.shape[1]//2}~{firing_data.shape[1]-1}")
print("Done!")
# Out:
# Step 1: Feature grouping...
# orientation.shape=(5805,),firing_data.shape=(5805, 172),spatial_frequency.shape=(5805,),phase.shape=(5805,)
# Step 2: Computing modulation strength...
# Grouping data...
# Computing ANOVA...
# Step 3: Plotting radar charts...
# Done!

# %%
positions = all_roi_masks # 172*500*500
# modulation = {
#         'orientation': np.zeros(N_neurons),
#         'spatial_frequency': np.zeros(N_neurons),
#         'phase': np.zeros(N_neurons)
#     }
N_neurons = len(modulation['orientation'])
selective_cell_indexs = [idx  for idx in range(N_neurons) if modulation['orientation'][idx] > 2 or modulation['spatial_frequency'][idx] > 2]
simple_cells_indexs = [idx  for idx in range(N_neurons) if modulation['orientation'][idx] > 2 and modulation['spatial_frequency'][idx] > 2] # selective in spatial frequency
complex_cells_indexs = [idx  for idx in range(N_neurons) if modulation['orientation'][idx] > 2 and modulation['spatial_frequency'][idx] < 2] # not selective in spatial frequency

fig, ((ax1, ax2),(ax3,ax4)) = plt.subplots(2, 2, figsize=(12,6))
ax1.imshow(np.max(all_roi_masks,axis=0))
ax1.set_title('All ROIs')
ax2.imshow(np.max(all_roi_masks[selective_cell_indexs],axis=0))
ax2.set_title('Cells with selectivity in orientation or freqs')
ax3.imshow(np.max(all_roi_masks[simple_cells_indexs],axis=0))
ax3.set_title('Cells with selectivity in orientation and certain freqs')
ax4.imshow(np.max(all_roi_masks[complex_cells_indexs],axis=0))
ax4.set_title('Cells with selectivity in orientation only')
plt.show()

# %%
# print("Step 1: Feature grouping...")
# firing_datas = extract_feature_lists(firing_data, orientation, spatial_frequency, phase)
# firing_data_,orientation_,spatial_frequency_,phase_
# print(firing_datas)
import tqdm
neuron_num = firing_data.shape[1]
feature_selectivity = [[[],[],[]] for _ in range(neuron_num)]
single_feature = [feature[1:] for feature in firing_datas]
for i in tqdm.trange(neuron_num):
    for feature in firing_datas:
        feature_selectivity[i][0].append([feature[1],np.mean(feature[0][:,i])]) # orientation
        feature_selectivity[i][1].append([feature[2],np.mean(feature[0][:,i])])  # spatial_frequency
        feature_selectivity[i][2].append([feature[3],np.mean(feature[0][:,i])])  # phase


def analyze_feature_selectivity_with_anova(neuron_data, neuron_idx=None, ifshow=True): 
    """
    对一个神经元的 orientation、spatial frequency 和 phase 响应数据进行 ANOVA 分析，并绘图。
    
    参数:
        neuron_data: 一个长度为3的列表，包含：
            neuron_data[0] -> orientation 数据，格式为 [[feature_value, response], ...]
            neuron_data[1] -> spatial_frequency 数据
            neuron_data[2] -> phase 数据
        neuron_idx: 当前神经元编号（可选，用于显示）
    """
    feature_names = ['Orientation', 'Spatial Frequency', 'Phase']
    
    if ifshow:
        fig, axs = plt.subplots(1, 3, figsize=(18, 6))
    
    results = {}

    for i in range(3):
        data = np.array(neuron_data[i])
        x = data[:, 0].astype(float)  # 特征值
        y = data[:, 1].astype(float)  # 响应值

        # 按照不同特征值分组
        unique_vals = np.unique(x)
        groups = [y[x == val] for val in unique_vals]

        # 过滤掉空组（防止报错）
        groups = [g for g in groups if len(g) > 0]

        # 至少需要两组才能做 ANOVA
        if len(groups) < 2:
            print(f"[Neuron {neuron_idx}] Not enough groups for {feature_names[i]} (n={len(groups)})")
            continue

        # 执行 One-way ANOVA
        f_stat, p_val = f_oneway(*groups)

        # 输出结果
        print(f"[Neuron {neuron_idx}] {feature_names[i]:<15} F = {f_stat:.4f}, p = {p_val:.4f}")

        # 存储结果
        results[feature_names[i]] = {'F': f_stat, 'p': p_val}
        if ifshow:
            # 绘图
            axs[i].scatter(x, y, alpha=0.7, label='Data')
            axs[i].set_title(f"{feature_names[i]}\nF={f_stat:.2f}, p={p_val:.4f}")
            axs[i].set_xlabel('Feature Value')
            axs[i].set_ylabel('Mean Response')
            axs[i].grid(True)

    if ifshow:
        plt.tight_layout()
        if neuron_idx is not None:
            plt.suptitle(f"Neuron {neuron_idx} Feature Selectivity with ANOVA", y=1.05)
        plt.show()

    return results

def plot_feature_selectivity(neuron_data):
    """
    绘制单个神经元对 orientation、spatial frequency 和 phase 的响应散点图。
    
    参数:
        neuron_data: 一个长度为3的列表，包含：
            neuron_data[0] -> orientation 数据，格式为 [[feature_value, response], ...]
            neuron_data[1] -> spatial_frequency 数据
            neuron_data[2] -> phase 数据
    """
    labels = ['Orientation', 'Spatial Frequency', 'Phase']
    
    fig, axs = plt.subplots(1, 3, figsize=(15, 5))
    
    for i in range(3):
        data = np.array(neuron_data[i])
        x = data[:, 0].astype(float)  # 特征值
        y = data[:, 1].astype(float)  # 响应值
        
        axs[i].scatter(x, y)
        axs[i].set_title(labels[i])
        axs[i].set_xlabel('Feature Value')
        axs[i].set_ylabel('Mean Response')
        axs[i].grid(True)
        
    plt.tight_layout()
    plt.show()

def calculate_preference(feature_selectivity):
    all_results = []
    for neuron_idx, neuron_data in enumerate(tqdm.tqdm(feature_selectivity)):
        result = analyze_feature_selectivity_with_anova(neuron_data, neuron_idx=neuron_idx,ifshow=False)
        all_results.append(result)
    return all_results

Calculated_FP_ANOVA = calculate_preference(feature_selectivity)
# Out:
#   0%|          | 0/172 [00:00<?, ?it/s]
# 100%|██████████| 172/172 [00:00<00:00, 287.01it/s]
# 100%|██████████| 172/172 [00:00<00:00, 1463.23it/s]
# [Neuron 0] Orientation     F = 3.6649, p = 0.0041
# [Neuron 0] Spatial Frequency F = 10.2977, p = 0.0000
# [Neuron 0] Phase           F = 0.3718, p = 0.7735
# [Neuron 1] Orientation     F = 2.3701, p = 0.0437
# [Neuron 1] Spatial Frequency F = 3.5135, p = 0.0096
# [Neuron 1] Phase           F = 0.4623, p = 0.7092
# [Neuron 2] Orientation     F = 0.9390, p = 0.4587
# [Neuron 2] Spatial Frequency F = 2.0349, p = 0.0941
# [Neuron 2] Phase           F = 1.5641, p = 0.2019
# [Neuron 3] Orientation     F = 0.7472, p = 0.5898
# [Neuron 3] Spatial Frequency F = 1.7220, p = 0.1499
# [Neuron 3] Phase           F = 0.3510, p = 0.7885
# [Neuron 4] Orientation     F = 1.1437, p = 0.3415
# [Neuron 4] Spatial Frequency F = 0.6189, p = 0.6499
# [Neuron 4] Phase           F = 0.3487, p = 0.7902
# [Neuron 5] Orientation     F = 2.0054, p = 0.0831
# [Neuron 5] Spatial Frequency F = 0.3219, p = 0.8628
# [Neuron 5] Phase           F = 0.6741, p = 0.5696
# [Neuron 6] Orientation     F = 0.9483, p = 0.4528
# [Neuron 6] Spatial Frequency F = 0.3025, p = 0.8758
# [Neuron 6] Phase           F = 1.3119, p = 0.2739
# [Neuron 7] Orientation     F = 0.5309, p = 0.7525
# [Neuron 7] Spatial Frequency F = 10.3638, p = 0.0000
# [Neuron 7] Phase           F = 0.1867, p = 0.9053
# [Neuron 8] Orientation     F = 2.5862, p = 0.0296
# [Neuron 8] Spatial Frequency F = 4.0168, p = 0.0044
# [Neuron 8] Phase           F = 0.6430, p = 0.5889
# [Neuron 9] Orientation     F = 0.9633, p = 0.4434
# [Neuron 9] Spatial Frequency F = 3.3144, p = 0.0131
# [Neuron 9] Phase           F = 0.4275, p = 0.7336
# [Neuron 10] Orientation     F = 0.8660, p = 0.5063
# [Neuron 10] Spatial Frequency F = 6.6905, p = 0.0001
# [Neuron 10] Phase           F = 1.4094, p = 0.2436
# [Neuron 11] Orientation     F = 2.9033, p = 0.0167
# [Neuron 11] Spatial Frequency F = 5.6026, p = 0.0004
# [Neuron 11] Phase           F = 1.5725, p = 0.1998
# [Neuron 12] Orientation     F = 0.9428, p = 0.4562
# [Neuron 12] Spatial Frequency F = 4.3348, p = 0.0027
# [Neuron 12] Phase           F = 0.3076, p = 0.8199
# [Neuron 13] Orientation     F = 2.6562, p = 0.0261
# [Neuron 13] Spatial Frequency F = 3.7954, p = 0.0062
# [Neuron 13] Phase           F = 0.0612, p = 0.9801
# [Neuron 14] Orientation     F = 0.7371, p = 0.5972
# [Neuron 14] Spatial Frequency F = 2.4966, p = 0.0466
# [Neuron 14] Phase           F = 1.0400, p = 0.3776
# [Neuron 15] Orientation     F = 0.5703, p = 0.7226
# [Neuron 15] Spatial Frequency F = 5.6934, p = 0.0003
# [Neuron 15] Phase           F = 0.1683, p = 0.9176
# [Neuron 16] Orientation     F = 1.2749, p = 0.2796
# [Neuron 16] Spatial Frequency F = 5.2749, p = 0.0006
# [Neuron 16] Phase           F = 0.2343, p = 0.8723
# [Neuron 17] Orientation     F = 0.2828, p = 0.9217
# [Neuron 17] Spatial Frequency F = 3.6692, p = 0.0075
# [Neuron 17] Phase           F = 1.3356, p = 0.2663
# [Neuron 18] Orientation     F = 0.5722, p = 0.7211
# [Neuron 18] Spatial Frequency F = 1.4796, p = 0.2129
# [Neuron 18] Phase           F = 1.8379, p = 0.1441
# [Neuron 19] Orientation     F = 1.4324, p = 0.2179
# [Neuron 19] Spatial Frequency F = 5.0571, p = 0.0009
# [Neuron 19] Phase           F = 0.4134, p = 0.7437
# [Neuron 20] Orientation     F = 1.3612, p = 0.2442
# [Neuron 20] Spatial Frequency F = 3.4808, p = 0.0101
# [Neuron 20] Phase           F = 1.2790, p = 0.2849
# [Neuron 21] Orientation     F = 0.8045, p = 0.5487
# [Neuron 21] Spatial Frequency F = 0.8354, p = 0.5054
# [Neuron 21] Phase           F = 0.7623, p = 0.5174
# [Neuron 22] Orientation     F = 0.7447, p = 0.5916
# [Neuron 22] Spatial Frequency F = 4.5706, p = 0.0018
# [Neuron 22] Phase           F = 0.3221, p = 0.8094
# [Neuron 23] Orientation     F = 1.8029, p = 0.1178
# [Neuron 23] Spatial Frequency F = 6.2208, p = 0.0001
# [Neuron 23] Phase           F = 0.0718, p = 0.9749
# [Neuron 24] Orientation     F = 17.6184, p = 0.0000
# [Neuron 24] Spatial Frequency F = 3.5094, p = 0.0097
# [Neuron 24] Phase           F = 0.0315, p = 0.9924
# [Neuron 25] Orientation     F = 2.4191, p = 0.0400
# [Neuron 25] Spatial Frequency F = 5.4041, p = 0.0005
# [Neuron 25] Phase           F = 0.3818, p = 0.7663
# [Neuron 26] Orientation     F = 3.4573, p = 0.0060
# [Neuron 26] Spatial Frequency F = 6.6192, p = 0.0001
# [Neuron 26] Phase           F = 0.9279, p = 0.4297
# [Neuron 27] Orientation     F = 1.2336, p = 0.2980
# [Neuron 27] Spatial Frequency F = 1.9214, p = 0.1115
# [Neuron 27] Phase           F = 0.4334, p = 0.7295
# [Neuron 28] Orientation     F = 4.2354, p = 0.0014
# [Neuron 28] Spatial Frequency F = 2.7407, p = 0.0320
# [Neuron 28] Phase           F = 0.1007, p = 0.9595
# [Neuron 29] Orientation     F = 1.4029, p = 0.2285
# [Neuron 29] Spatial Frequency F = 1.3566, p = 0.2534
# [Neuron 29] Phase           F = 2.0638, p = 0.1088
# [Neuron 30] Orientation     F = 0.8486, p = 0.5182
# [Neuron 30] Spatial Frequency F = 1.8056, p = 0.1325
# [Neuron 30] Phase           F = 0.6888, p = 0.5607
# [Neuron 31] Orientation     F = 1.0496, p = 0.3922
# [Neuron 31] Spatial Frequency F = 1.2849, p = 0.2800
# [Neuron 31] Phase           F = 0.4295, p = 0.7322
# [Neuron 32] Orientation     F = 0.8329, p = 0.5289
# [Neuron 32] Spatial Frequency F = 1.3984, p = 0.2389
# [Neuron 32] Phase           F = 0.8014, p = 0.4956
# [Neuron 33] Orientation     F = 0.4852, p = 0.7867
# [Neuron 33] Spatial Frequency F = 11.8693, p = 0.0000
# [Neuron 33] Phase           F = 1.1623, p = 0.3273
# [Neuron 34] Orientation     F = 1.8940, p = 0.1008
# [Neuron 34] Spatial Frequency F = 2.1485, p = 0.0793
# [Neuron 34] Phase           F = 0.9322, p = 0.4276
# [Neuron 35] Orientation     F = 3.8660, p = 0.0028
# [Neuron 35] Spatial Frequency F = 3.3822, p = 0.0118
# [Neuron 35] Phase           F = 0.1976, p = 0.8978
# [Neuron 36] Orientation     F = 1.5432, p = 0.1820
# [Neuron 36] Spatial Frequency F = 2.5616, p = 0.0421
# [Neuron 36] Phase           F = 0.6432, p = 0.5888
# [Neuron 37] Orientation     F = 0.2360, p = 0.9459
# [Neuron 37] Spatial Frequency F = 2.7918, p = 0.0295
# [Neuron 37] Phase           F = 0.8536, p = 0.4674
# [Neuron 38] Orientation     F = 0.6949, p = 0.6283
# [Neuron 38] Spatial Frequency F = 3.1405, p = 0.0172
# [Neuron 38] Phase           F = 2.1347, p = 0.0996
# [Neuron 39] Orientation     F = 1.5425, p = 0.1822
# [Neuron 39] Spatial Frequency F = 3.9360, p = 0.0050
# [Neuron 39] Phase           F = 0.1173, p = 0.9498
# [Neuron 40] Orientation     F = 1.3133, p = 0.2634
# [Neuron 40] Spatial Frequency F = 29.4096, p = 0.0000
# [Neuron 40] Phase           F = 0.3576, p = 0.7837
# [Neuron 41] Orientation     F = 7.3837, p = 0.0000
# [Neuron 41] Spatial Frequency F = 7.9321, p = 0.0000
# [Neuron 41] Phase           F = 0.0837, p = 0.9688
# [Neuron 42] Orientation     F = 2.7678, p = 0.0213
# [Neuron 42] Spatial Frequency F = 1.6369, p = 0.1697
# [Neuron 42] Phase           F = 1.2541, p = 0.2935
# [Neuron 43] Orientation     F = 0.2646, p = 0.9316
# [Neuron 43] Spatial Frequency F = 1.3201, p = 0.2667
# [Neuron 43] Phase           F = 0.1773, p = 0.9116
# [Neuron 44] Orientation     F = 0.8131, p = 0.5427
# [Neuron 44] Spatial Frequency F = 1.2939, p = 0.2766
# [Neuron 44] Phase           F = 0.3921, p = 0.7589
# [Neuron 45] Orientation     F = 3.5064, p = 0.0055
# [Neuron 45] Spatial Frequency F = 4.0205, p = 0.0043
# [Neuron 45] Phase           F = 1.6062, p = 0.1917
# [Neuron 46] Orientation     F = 7.1427, p = 0.0000
# [Neuron 46] Spatial Frequency F = 3.1624, p = 0.0166
# [Neuron 46] Phase           F = 0.6038, p = 0.6138
# [Neuron 47] Orientation     F = 2.3620, p = 0.0443
# [Neuron 47] Spatial Frequency F = 3.5265, p = 0.0094
# [Neuron 47] Phase           F = 0.3911, p = 0.7596
# [Neuron 48] Orientation     F = 2.5430, p = 0.0320
# [Neuron 48] Spatial Frequency F = 8.6908, p = 0.0000
# [Neuron 48] Phase           F = 0.0830, p = 0.9692
# [Neuron 49] Orientation     F = 5.3468, p = 0.0002
# [Neuron 49] Spatial Frequency F = 1.1713, p = 0.3272
# [Neuron 49] Phase           F = 0.0964, p = 0.9619
# [Neuron 50] Orientation     F = 2.6249, p = 0.0276
# [Neuron 50] Spatial Frequency F = 1.8678, p = 0.1208
# [Neuron 50] Phase           F = 0.5240, p = 0.6666
# [Neuron 51] Orientation     F = 3.0576, p = 0.0126
# [Neuron 51] Spatial Frequency F = 3.7969, p = 0.0062
# [Neuron 51] Phase           F = 0.4887, p = 0.6908
# [Neuron 52] Orientation     F = 0.3493, p = 0.8818
# [Neuron 52] Spatial Frequency F = 11.9899, p = 0.0000
# [Neuron 52] Phase           F = 1.6563, p = 0.1803
# [Neuron 53] Orientation     F = 0.8610, p = 0.5098
# [Neuron 53] Spatial Frequency F = 16.9841, p = 0.0000
# [Neuron 53] Phase           F = 0.1932, p = 0.9009
# [Neuron 54] Orientation     F = 0.2295, p = 0.9490
# [Neuron 54] Spatial Frequency F = 11.0257, p = 0.0000
# [Neuron 54] Phase           F = 0.2292, p = 0.8759
# [Neuron 55] Orientation     F = 0.1647, p = 0.9750
# [Neuron 55] Spatial Frequency F = 3.6498, p = 0.0077
# [Neuron 55] Phase           F = 0.2262, p = 0.8780
# [Neuron 56] Orientation     F = 1.9282, p = 0.0950
# [Neuron 56] Spatial Frequency F = 12.1532, p = 0.0000
# [Neuron 56] Phase           F = 0.5333, p = 0.6603
# [Neuron 57] Orientation     F = 7.6706, p = 0.0000
# [Neuron 57] Spatial Frequency F = 4.9427, p = 0.0010
# [Neuron 57] Phase           F = 0.0184, p = 0.9966
# [Neuron 58] Orientation     F = 0.9941, p = 0.4247
# [Neuron 58] Spatial Frequency F = 46.5886, p = 0.0000
# [Neuron 58] Phase           F = 0.0518, p = 0.9844
# [Neuron 59] Orientation     F = 2.4535, p = 0.0376
# [Neuron 59] Spatial Frequency F = 1.9011, p = 0.1150
# [Neuron 59] Phase           F = 1.6226, p = 0.1879
# [Neuron 60] Orientation     F = 2.5085, p = 0.0341
# [Neuron 60] Spatial Frequency F = 5.1094, p = 0.0008
# [Neuron 60] Phase           F = 0.0535, p = 0.9836
# [Neuron 61] Orientation     F = 1.1566, p = 0.3350
# [Neuron 61] Spatial Frequency F = 8.3063, p = 0.0000
# [Neuron 61] Phase           F = 1.3223, p = 0.2706
# [Neuron 62] Orientation     F = 2.5479, p = 0.0317
# [Neuron 62] Spatial Frequency F = 4.5771, p = 0.0018
# [Neuron 62] Phase           F = 0.1018, p = 0.9588
# [Neuron 63] Orientation     F = 0.8550, p = 0.5138
# [Neuron 63] Spatial Frequency F = 1.2581, p = 0.2906
# [Neuron 63] Phase           F = 1.2852, p = 0.2828
# [Neuron 64] Orientation     F = 2.8354, p = 0.0188
# [Neuron 64] Spatial Frequency F = 7.0407, p = 0.0000
# [Neuron 64] Phase           F = 0.3445, p = 0.7932
# [Neuron 65] Orientation     F = 1.9555, p = 0.0906
# [Neuron 65] Spatial Frequency F = 2.7258, p = 0.0327
# [Neuron 65] Phase           F = 0.5777, p = 0.6308
# [Neuron 66] Orientation     F = 0.6399, p = 0.6697
# [Neuron 66] Spatial Frequency F = 4.4635, p = 0.0022
# [Neuron 66] Phase           F = 0.1316, p = 0.9411
# [Neuron 67] Orientation     F = 0.7509, p = 0.5871
# [Neuron 67] Spatial Frequency F = 10.4289, p = 0.0000
# [Neuron 67] Phase           F = 0.0940, p = 0.9632
# [Neuron 68] Orientation     F = 1.5743, p = 0.1729
# [Neuron 68] Spatial Frequency F = 1.0410, p = 0.3892
# [Neuron 68] Phase           F = 0.8618, p = 0.4631
# [Neuron 69] Orientation     F = 0.8388, p = 0.5248
# [Neuron 69] Spatial Frequency F = 0.8519, p = 0.4953
# [Neuron 69] Phase           F = 0.4903, p = 0.6897
# [Neuron 70] Orientation     F = 1.8918, p = 0.1012
# [Neuron 70] Spatial Frequency F = 0.1252, p = 0.9731
# [Neuron 70] Phase           F = 0.8377, p = 0.4758
# [Neuron 71] Orientation     F = 0.8278, p = 0.5325
# [Neuron 71] Spatial Frequency F = 2.3822, p = 0.0555
# [Neuron 71] Phase           F = 0.4512, p = 0.7169
# [Neuron 72] Orientation     F = 0.3054, p = 0.9088
# [Neuron 72] Spatial Frequency F = 1.5876, p = 0.1823
# [Neuron 72] Phase           F = 0.0203, p = 0.9961
# [Neuron 73] Orientation     F = 1.5341, p = 0.1847
# [Neuron 73] Spatial Frequency F = 2.7668, p = 0.0307
# [Neuron 73] Phase           F = 1.6390, p = 0.1842
# [Neuron 74] Orientation     F = 1.1240, p = 0.3517
# [Neuron 74] Spatial Frequency F = 4.0072, p = 0.0044
# [Neuron 74] Phase           F = 0.2182, p = 0.8836
# [Neuron 75] Orientation     F = 5.8611, p = 0.0001
# [Neuron 75] Spatial Frequency F = 2.7703, p = 0.0305
# [Neuron 75] Phase           F = 0.4527, p = 0.7159
# [Neuron 76] Orientation     F = 0.1323, p = 0.9847
# [Neuron 76] Spatial Frequency F = 3.5998, p = 0.0084
# [Neuron 76] Phase           F = 0.3072, p = 0.8201
# [Neuron 77] Orientation     F = 0.7955, p = 0.5551
# [Neuron 77] Spatial Frequency F = 0.8540, p = 0.4940
# [Neuron 77] Phase           F = 1.3148, p = 0.2730
# [Neuron 78] Orientation     F = 1.7439, p = 0.1302
# [Neuron 78] Spatial Frequency F = 11.0020, p = 0.0000
# [Neuron 78] Phase           F = 0.3077, p = 0.8198
# [Neuron 79] Orientation     F = 1.7451, p = 0.1299
# [Neuron 79] Spatial Frequency F = 2.7357, p = 0.0322
# [Neuron 79] Phase           F = 1.1085, p = 0.3486
# [Neuron 80] Orientation     F = 2.0077, p = 0.0828
# [Neuron 80] Spatial Frequency F = 7.7232, p = 0.0000
# [Neuron 80] Phase           F = 0.4089, p = 0.7469
# [Neuron 81] Orientation     F = 5.1631, p = 0.0003
# [Neuron 81] Spatial Frequency F = 0.9621, p = 0.4312
# [Neuron 81] Phase           F = 1.4410, p = 0.2345
# [Neuron 82] Orientation     F = 0.8690, p = 0.5044
# [Neuron 82] Spatial Frequency F = 15.9889, p = 0.0000
# [Neuron 82] Phase           F = 1.0888, p = 0.3568
# [Neuron 83] Orientation     F = 0.6975, p = 0.6264
# [Neuron 83] Spatial Frequency F = 1.4630, p = 0.2180
# [Neuron 83] Phase           F = 0.3486, p = 0.7903
# [Neuron 84] Orientation     F = 5.2480, p = 0.0002
# [Neuron 84] Spatial Frequency F = 7.4706, p = 0.0000
# [Neuron 84] Phase           F = 1.0902, p = 0.3562
# [Neuron 85] Orientation     F = 0.0879, p = 0.9940
# [Neuron 85] Spatial Frequency F = 4.8124, p = 0.0013
# [Neuron 85] Phase           F = 0.4026, p = 0.7514
# [Neuron 86] Orientation     F = 1.0363, p = 0.3998
# [Neuron 86] Spatial Frequency F = 1.8646, p = 0.1214
# [Neuron 86] Phase           F = 0.1351, p = 0.9389
# [Neuron 87] Orientation     F = 1.5384, p = 0.1835
# [Neuron 87] Spatial Frequency F = 2.6642, p = 0.0360
# [Neuron 87] Phase           F = 1.5731, p = 0.1997
# [Neuron 88] Orientation     F = 2.6788, p = 0.0250
# [Neuron 88] Spatial Frequency F = 11.8115, p = 0.0000
# [Neuron 88] Phase           F = 0.1458, p = 0.9322
# [Neuron 89] Orientation     F = 1.4567, p = 0.2096
# [Neuron 89] Spatial Frequency F = 1.1487, p = 0.3373
# [Neuron 89] Phase           F = 0.5384, p = 0.6569
# [Neuron 90] Orientation     F = 2.1073, p = 0.0695
# [Neuron 90] Spatial Frequency F = 3.7127, p = 0.0070
# [Neuron 90] Phase           F = 0.7617, p = 0.5178
# [Neuron 91] Orientation     F = 0.3668, p = 0.8704
# [Neuron 91] Spatial Frequency F = 4.5800, p = 0.0018
# [Neuron 91] Phase           F = 0.3975, p = 0.7550
# [Neuron 92] Orientation     F = 1.0992, p = 0.3648
# [Neuron 92] Spatial Frequency F = 3.0498, p = 0.0198
# [Neuron 92] Phase           F = 0.5817, p = 0.6282
# [Neuron 93] Orientation     F = 1.2933, p = 0.2717
# [Neuron 93] Spatial Frequency F = 18.5699, p = 0.0000
# [Neuron 93] Phase           F = 0.4840, p = 0.6940
# [Neuron 94] Orientation     F = 1.5535, p = 0.1790
# [Neuron 94] Spatial Frequency F = 3.4210, p = 0.0111
# [Neuron 94] Phase           F = 0.4031, p = 0.7510
# [Neuron 95] Orientation     F = 7.8729, p = 0.0000
# [Neuron 95] Spatial Frequency F = 8.6079, p = 0.0000
# [Neuron 95] Phase           F = 0.3227, p = 0.8090
# [Neuron 96] Orientation     F = 2.2658, p = 0.0526
# [Neuron 96] Spatial Frequency F = 8.3285, p = 0.0000
# [Neuron 96] Phase           F = 0.4265, p = 0.7344
# [Neuron 97] Orientation     F = 0.4888, p = 0.7840
# [Neuron 97] Spatial Frequency F = 4.0075, p = 0.0044
# [Neuron 97] Phase           F = 0.1424, p = 0.9343
# [Neuron 98] Orientation     F = 3.3949, p = 0.0068
# [Neuron 98] Spatial Frequency F = 0.5039, p = 0.7329
# [Neuron 98] Phase           F = 1.2004, p = 0.3129
# [Neuron 99] Orientation     F = 1.6237, p = 0.1593
# [Neuron 99] Spatial Frequency F = 0.4736, p = 0.7550
# [Neuron 99] Phase           F = 1.4327, p = 0.2368
# [Neuron 100] Orientation     F = 0.6416, p = 0.6684
# [Neuron 100] Spatial Frequency F = 7.5828, p = 0.0000
# [Neuron 100] Phase           F = 0.0567, p = 0.9822
# [Neuron 101] Orientation     F = 2.4554, p = 0.0375
# [Neuron 101] Spatial Frequency F = 7.3994, p = 0.0000
# [Neuron 101] Phase           F = 0.4353, p = 0.7281
# [Neuron 102] Orientation     F = 1.1487, p = 0.3390
# [Neuron 102] Spatial Frequency F = 12.6867, p = 0.0000
# [Neuron 102] Phase           F = 0.9377, p = 0.4249
# [Neuron 103] Orientation     F = 0.9897, p = 0.4273
# [Neuron 103] Spatial Frequency F = 4.7173, p = 0.0015
# [Neuron 103] Phase           F = 0.5483, p = 0.6502
# [Neuron 104] Orientation     F = 2.5155, p = 0.0336
# [Neuron 104] Spatial Frequency F = 4.0924, p = 0.0039
# [Neuron 104] Phase           F = 0.5817, p = 0.6282
# [Neuron 105] Orientation     F = 0.7297, p = 0.6026
# [Neuron 105] Spatial Frequency F = 2.2552, p = 0.0674
# [Neuron 105] Phase           F = 0.0295, p = 0.9931
# [Neuron 106] Orientation     F = 1.5374, p = 0.1837
# [Neuron 106] Spatial Frequency F = 0.9203, p = 0.4547
# [Neuron 106] Phase           F = 2.1262, p = 0.1007
# [Neuron 107] Orientation     F = 1.3570, p = 0.2458
# [Neuron 107] Spatial Frequency F = 4.7101, p = 0.0015
# [Neuron 107] Phase           F = 0.9018, p = 0.4427
# [Neuron 108] Orientation     F = 0.4966, p = 0.7783
# [Neuron 108] Spatial Frequency F = 2.2667, p = 0.0662
# [Neuron 108] Phase           F = 0.0934, p = 0.9635
# [Neuron 109] Orientation     F = 1.7018, p = 0.1398
# [Neuron 109] Spatial Frequency F = 7.6492, p = 0.0000
# [Neuron 109] Phase           F = 1.5748, p = 0.1992
# [Neuron 110] Orientation     F = 5.4657, p = 0.0002
# [Neuron 110] Spatial Frequency F = 2.5496, p = 0.0429
# [Neuron 110] Phase           F = 0.1722, p = 0.9150
# [Neuron 111] Orientation     F = 1.6945, p = 0.1415
# [Neuron 111] Spatial Frequency F = 1.4776, p = 0.2135
# [Neuron 111] Phase           F = 3.0723, p = 0.0306
# [Neuron 112] Orientation     F = 0.8681, p = 0.5049
# [Neuron 112] Spatial Frequency F = 3.2186, p = 0.0152
# [Neuron 112] Phase           F = 0.2805, p = 0.8394
# [Neuron 113] Orientation     F = 0.2964, p = 0.9140
# [Neuron 113] Spatial Frequency F = 3.8145, p = 0.0060
# [Neuron 113] Phase           F = 0.7432, p = 0.5284
# [Neuron 114] Orientation     F = 1.9578, p = 0.0903
# [Neuron 114] Spatial Frequency F = 1.5080, p = 0.2045
# [Neuron 114] Phase           F = 1.3659, p = 0.2567
# [Neuron 115] Orientation     F = 3.0780, p = 0.0121
# [Neuron 115] Spatial Frequency F = 1.7315, p = 0.1478
# [Neuron 115] Phase           F = 0.4381, p = 0.7261
# [Neuron 116] Orientation     F = 1.3406, p = 0.2523
# [Neuron 116] Spatial Frequency F = 1.1074, p = 0.3565
# [Neuron 116] Phase           F = 0.5866, p = 0.6250
# [Neuron 117] Orientation     F = 1.3394, p = 0.2528
# [Neuron 117] Spatial Frequency F = 16.5534, p = 0.0000
# [Neuron 117] Phase           F = 0.0864, p = 0.9674
# [Neuron 118] Orientation     F = 0.4223, p = 0.8323
# [Neuron 118] Spatial Frequency F = 3.7882, p = 0.0062
# [Neuron 118] Phase           F = 0.1175, p = 0.9497
# [Neuron 119] Orientation     F = 2.9526, p = 0.0152
# [Neuron 119] Spatial Frequency F = 2.4339, p = 0.0513
# [Neuron 119] Phase           F = 0.1149, p = 0.9512
# [Neuron 120] Orientation     F = 5.9454, p = 0.0001
# [Neuron 120] Spatial Frequency F = 3.7647, p = 0.0065
# [Neuron 120] Phase           F = 0.6281, p = 0.5983
# [Neuron 121] Orientation     F = 0.4139, p = 0.8383
# [Neuron 121] Spatial Frequency F = 13.8208, p = 0.0000
# [Neuron 121] Phase           F = 0.5445, p = 0.6528
# [Neuron 122] Orientation     F = 3.0265, p = 0.0133
# [Neuron 122] Spatial Frequency F = 6.6586, p = 0.0001
# [Neuron 122] Phase           F = 0.2961, p = 0.8281
# [Neuron 123] Orientation     F = 1.3922, p = 0.2324
# [Neuron 123] Spatial Frequency F = 2.7510, p = 0.0315
# [Neuron 123] Phase           F = 1.0800, p = 0.3605
# [Neuron 124] Orientation     F = 0.6683, p = 0.6483
# [Neuron 124] Spatial Frequency F = 2.0507, p = 0.0919
# [Neuron 124] Phase           F = 2.0082, p = 0.1167
# [Neuron 125] Orientation     F = 1.7078, p = 0.1384
# [Neuron 125] Spatial Frequency F = 5.5791, p = 0.0004
# [Neuron 125] Phase           F = 1.0867, p = 0.3576
# [Neuron 126] Orientation     F = 1.4274, p = 0.2197
# [Neuron 126] Spatial Frequency F = 5.0770, p = 0.0008
# [Neuron 126] Phase           F = 1.5439, p = 0.2069
# [Neuron 127] Orientation     F = 0.8214, p = 0.5369
# [Neuron 127] Spatial Frequency F = 1.1543, p = 0.3348
# [Neuron 127] Phase           F = 0.1480, p = 0.9308
# [Neuron 128] Orientation     F = 0.7750, p = 0.5697
# [Neuron 128] Spatial Frequency F = 2.2427, p = 0.0687
# [Neuron 128] Phase           F = 0.6248, p = 0.6004
# [Neuron 129] Orientation     F = 2.4053, p = 0.0410
# [Neuron 129] Spatial Frequency F = 9.7338, p = 0.0000
# [Neuron 129] Phase           F = 0.7878, p = 0.5031
# [Neuron 130] Orientation     F = 0.9822, p = 0.4318
# [Neuron 130] Spatial Frequency F = 1.5030, p = 0.2059
# [Neuron 130] Phase           F = 0.7471, p = 0.5262
# [Neuron 131] Orientation     F = 0.9564, p = 0.4477
# [Neuron 131] Spatial Frequency F = 2.6630, p = 0.0360
# [Neuron 131] Phase           F = 0.8450, p = 0.4719
# [Neuron 132] Orientation     F = 1.7500, p = 0.1289
# [Neuron 132] Spatial Frequency F = 11.7556, p = 0.0000
# [Neuron 132] Phase           F = 0.1674, p = 0.9182
# [Neuron 133] Orientation     F = 0.5164, p = 0.7634
# [Neuron 133] Spatial Frequency F = 2.2655, p = 0.0664
# [Neuron 133] Phase           F = 0.2544, p = 0.8580
# [Neuron 134] Orientation     F = 1.0193, p = 0.4097
# [Neuron 134] Spatial Frequency F = 5.3623, p = 0.0005
# [Neuron 134] Phase           F = 0.7773, p = 0.5090
# [Neuron 135] Orientation     F = 0.9805, p = 0.4329
# [Neuron 135] Spatial Frequency F = 5.6830, p = 0.0003
# [Neuron 135] Phase           F = 2.1188, p = 0.1016
# [Neuron 136] Orientation     F = 0.8167, p = 0.5402
# [Neuron 136] Spatial Frequency F = 4.4134, p = 0.0023
# [Neuron 136] Phase           F = 1.0311, p = 0.3816
# [Neuron 137] Orientation     F = 0.3642, p = 0.8721
# [Neuron 137] Spatial Frequency F = 9.5312, p = 0.0000
# [Neuron 137] Phase           F = 0.3000, p = 0.8254
# [Neuron 138] Orientation     F = 2.8624, p = 0.0179
# [Neuron 138] Spatial Frequency F = 1.8973, p = 0.1156
# [Neuron 138] Phase           F = 1.2731, p = 0.2869
# [Neuron 139] Orientation     F = 1.1298, p = 0.3487
# [Neuron 139] Spatial Frequency F = 4.1448, p = 0.0036
# [Neuron 139] Phase           F = 0.1070, p = 0.9559
# [Neuron 140] Orientation     F = 0.4945, p = 0.7798
# [Neuron 140] Spatial Frequency F = 4.1350, p = 0.0036
# [Neuron 140] Phase           F = 0.0984, p = 0.9607
# [Neuron 141] Orientation     F = 4.6907, p = 0.0006
# [Neuron 141] Spatial Frequency F = 4.9529, p = 0.0010
# [Neuron 141] Phase           F = 0.4761, p = 0.6995
# [Neuron 142] Orientation     F = 2.3740, p = 0.0433
# [Neuron 142] Spatial Frequency F = 3.7994, p = 0.0061
# [Neuron 142] Phase           F = 0.3302, p = 0.8035
# [Neuron 143] Orientation     F = 0.5048, p = 0.7721
# [Neuron 143] Spatial Frequency F = 5.1955, p = 0.0007
# [Neuron 143] Phase           F = 0.0033, p = 0.9997
# [Neuron 144] Orientation     F = 1.0057, p = 0.4177
# [Neuron 144] Spatial Frequency F = 2.5584, p = 0.0424
# [Neuron 144] Phase           F = 1.9206, p = 0.1301
# [Neuron 145] Orientation     F = 0.3564, p = 0.8772
# [Neuron 145] Spatial Frequency F = 1.6186, p = 0.1743
# [Neuron 145] Phase           F = 0.2384, p = 0.8694
# [Neuron 146] Orientation     F = 0.5637, p = 0.7276
# [Neuron 146] Spatial Frequency F = 1.8720, p = 0.1201
# [Neuron 146] Phase           F = 0.4635, p = 0.7083
# [Neuron 147] Orientation     F = 0.4880, p = 0.7846
# [Neuron 147] Spatial Frequency F = 4.8256, p = 0.0012
# [Neuron 147] Phase           F = 0.3039, p = 0.8225
# [Neuron 148] Orientation     F = 0.2485, p = 0.9398
# [Neuron 148] Spatial Frequency F = 1.6456, p = 0.1676
# [Neuron 148] Phase           F = 0.9258, p = 0.4307
# [Neuron 149] Orientation     F = 1.4933, p = 0.1975
# [Neuron 149] Spatial Frequency F = 2.7719, p = 0.0305
# [Neuron 149] Phase           F = 0.0808, p = 0.9703
# [Neuron 150] Orientation     F = 0.9900, p = 0.4271
# [Neuron 150] Spatial Frequency F = 15.1689, p = 0.0000
# [Neuron 150] Phase           F = 0.5969, p = 0.6183
# [Neuron 151] Orientation     F = 0.6206, p = 0.6843
# [Neuron 151] Spatial Frequency F = 5.7316, p = 0.0003
# [Neuron 151] Phase           F = 1.4877, p = 0.2216
# [Neuron 152] Orientation     F = 0.4362, p = 0.8225
# [Neuron 152] Spatial Frequency F = 11.1138, p = 0.0000
# [Neuron 152] Phase           F = 1.5768, p = 0.1988
# [Neuron 153] Orientation     F = 0.1731, p = 0.9721
# [Neuron 153] Spatial Frequency F = 25.4781, p = 0.0000
# [Neuron 153] Phase           F = 0.4606, p = 0.7103
# [Neuron 154] Orientation     F = 1.2965, p = 0.2704
# [Neuron 154] Spatial Frequency F = 0.7000, p = 0.5935
# [Neuron 154] Phase           F = 0.1752, p = 0.9130
# [Neuron 155] Orientation     F = 2.9508, p = 0.0153
# [Neuron 155] Spatial Frequency F = 1.5924, p = 0.1810
# [Neuron 155] Phase           F = 0.4593, p = 0.7113
# [Neuron 156] Orientation     F = 1.5146, p = 0.1907
# [Neuron 156] Spatial Frequency F = 3.3612, p = 0.0122
# [Neuron 156] Phase           F = 1.2967, p = 0.2790
# [Neuron 157] Orientation     F = 1.5183, p = 0.1896
# [Neuron 157] Spatial Frequency F = 3.5617, p = 0.0089
# [Neuron 157] Phase           F = 0.7947, p = 0.4993
# [Neuron 158] Orientation     F = 0.4414, p = 0.8188
# [Neuron 158] Spatial Frequency F = 0.7328, p = 0.5714
# [Neuron 158] Phase           F = 0.1375, p = 0.9375
# [Neuron 159] Orientation     F = 0.8772, p = 0.4989
# [Neuron 159] Spatial Frequency F = 0.6958, p = 0.5964
# [Neuron 159] Phase           F = 0.6759, p = 0.5685
# [Neuron 160] Orientation     F = 2.6065, p = 0.0285
# [Neuron 160] Spatial Frequency F = 1.2153, p = 0.3082
# [Neuron 160] Phase           F = 0.4155, p = 0.7422
# [Neuron 161] Orientation     F = 1.3298, p = 0.2566
# [Neuron 161] Spatial Frequency F = 2.1902, p = 0.0744
# [Neuron 161] Phase           F = 0.7990, p = 0.4969
# [Neuron 162] Orientation     F = 0.6410, p = 0.6688
# [Neuron 162] Spatial Frequency F = 1.6753, p = 0.1605
# [Neuron 162] Phase           F = 0.1038, p = 0.9577
# [Neuron 163] Orientation     F = 0.9897, p = 0.4273
# [Neuron 163] Spatial Frequency F = 0.7800, p = 0.5404
# [Neuron 163] Phase           F = 0.8126, p = 0.4894
# [Neuron 164] Orientation     F = 1.2376, p = 0.2962
# [Neuron 164] Spatial Frequency F = 2.6284, p = 0.0380
# [Neuron 164] Phase           F = 1.4730, p = 0.2255
# [Neuron 165] Orientation     F = 1.4944, p = 0.1971
# [Neuron 165] Spatial Frequency F = 0.4856, p = 0.7462
# [Neuron 165] Phase           F = 0.6293, p = 0.5975
# [Neuron 166] Orientation     F = 2.3169, p = 0.0480
# [Neuron 166] Spatial Frequency F = 2.6131, p = 0.0389
# [Neuron 166] Phase           F = 1.1304, p = 0.3398
# [Neuron 167] Orientation     F = 0.9176, p = 0.4723
# [Neuron 167] Spatial Frequency F = 8.5358, p = 0.0000
# [Neuron 167] Phase           F = 0.7130, p = 0.5462
# [Neuron 168] Orientation     F = 1.0302, p = 0.4034
# [Neuron 168] Spatial Frequency F = 8.8612, p = 0.0000
# [Neuron 168] Phase           F = 0.9836, p = 0.4031
# [Neuron 169] Orientation     F = 1.2520, p = 0.2897
# [Neuron 169] Spatial Frequency F = 7.1985, p = 0.0000
# [Neuron 169] Phase           F = 1.2407, p = 0.2982
# [Neuron 170] Orientation     F = 2.9643, p = 0.0149
# [Neuron 170] Spatial Frequency F = 3.6310, p = 0.0080
# [Neuron 170] Phase           F = 0.0833, p = 0.9690
# [Neuron 171] Orientation     F = 0.8239, p = 0.5351
# [Neuron 171] Spatial Frequency F = 11.7312, p = 0.0000
# [Neuron 171] Phase           F = 0.2920, p = 0.8311

# %%
Orientation_features = np.array([feature[0] for feature in single_feature])
Frequency_features = np.array([feature[1] for feature in single_feature])
Phase_features = np.array([feature[2] for feature in single_feature])
display_jittering = np.random.randn(len(Orientation_features),2)/50 # 创建一个随机的 jittering 矩阵，这样展示的时候比较好


Orientation_p = [0 if p_val['Orientation']['p']>0.05 else 1 for p_val in Calculated_FP_ANOVA]
Freq_p = [0 if p_val['Spatial Frequency']['p']>0.05 else 1 for p_val in Calculated_FP_ANOVA]
Phase_p = [0 if p_val['Phase']['p']>0.05 else 1 for p_val in Calculated_FP_ANOVA]

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6), subplot_kw={'projection': 'polar'})
ax1.set_thetalim(-np.pi/10, np.pi)
ax1.set_yscale('log')
ax2.set_thetalim(-np.pi/10, np.pi)
# 绘制第一个子图（Orientation vs. Frequency）
for i in range(len(Orientation_features)):
    theta = np.radians(Orientation_features[i])  # 将角度转换为弧度
    r = Frequency_features[i]  # 半径
    
    # 添加抖动
    jitter_theta = theta + display_jittering[i, 0]*2
    jitter_r = r  + display_jittering[i, 1]/10
    
    # 根据显著性选择颜色和标记
    color = 'red' if Freq_p[i] == 1 else 'blue'
    marker = '^' if Orientation_p[i] == 1 else 'o'
    
    ax1.plot(jitter_theta, jitter_r, marker=marker, color=color, markersize=5)
    
ax1.set_title('Orientation vs. Spatial Frequency',size=16)
ax1.set_ylim(0, max(Frequency_features) * 1.2)  # 设置 y 轴范围


legend_elements = [
    plt.Line2D([0], [0], marker='s', color='w', markerfacecolor='red', label='Frequency Significant',markersize=10),
    plt.Line2D([0], [0], marker='s', color='w', markerfacecolor='blue', label='Frequency Not Significant',markersize=10),
    plt.Line2D([0], [0], marker='^', color='w', markerfacecolor='black', label='Orientation Significant',markersize=10),
    plt.Line2D([0], [0], marker='o', color='w', markerfacecolor='black', label='Orientation Not Significant',markersize=10)
]
ax1.legend(handles=legend_elements, loc='lower left')
ax1.set_ylabel('Spatial Frequency')
ax1.set_yticks([0.04,0.08,0.16,0.32])
ax1.set_yticklabels(['0.04','0.08','0.16','0.32'])
ax1.grid(True)

# 绘制第二个子图（Orientation vs. Phase）
for i in range(len(Orientation_features)):
    theta = np.radians(Orientation_features[i])  # 将角度转换为弧度
    r = Phase_features[i]  # 半径
    
    # 添加抖动
    jitter_theta = theta + display_jittering[i, 0]
    jitter_r = r  + display_jittering[i, 1]
    
    # 根据显著性选择颜色和标记
    color = 'red' if Phase_p[i] == 1 else 'blue'
    marker = '^' if Orientation_p[i] == 1 else 'o'
    
    ax2.plot(jitter_theta, jitter_r, marker=marker, color=color, markersize=5)
    
ax2.set_title('Orientation vs. Phase',size=16)
ax2.set_ylim(0, max(Phase_features) * 1.2)  # 设置 y 轴范围
ax2.grid(True)

# 添加图例
legend_elements = [
    plt.Line2D([0], [0], marker='s', color='w', markerfacecolor='red', label='Phase Significant',markersize=10),
    plt.Line2D([0], [0], marker='s', color='w', markerfacecolor='blue', label='Phase Not Significant',markersize=10),
    plt.Line2D([0], [0], marker='^', color='w', markerfacecolor='black', label='Orientation Significant',markersize=10),
    plt.Line2D([0], [0], marker='o', color='w', markerfacecolor='black', label='Orientation Not Significant',markersize=10)
]
ax2.legend(handles=legend_elements, loc='lower left')
ax2.set_yticks([0,0.25,0.5,0.75,1])
ax2.set_yticklabels(['0','0.25','0.5','0.75','1'])
ax2.set_ylabel('Phase')
# 显示图形
plt.suptitle('Analysis for VISal Region',size=24)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\10690\AppData\Local\Temp\ipykernel_24836\1954818049.py:31: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax1.set_ylim(0, max(Frequency_features) * 1.2)  # 设置 y 轴范围
